# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
# Cargar datos
df = pd.read_excel('df_objetivo/df_objetivo_riesgo_real.xlsx')

# 1. Eliminar MUNICIPIO_RESIDENCIA
if 'MUNICIPIO_RESIDENCIA' in df.columns:
    df = df.drop(columns=['MUNICIPIO_RESIDENCIA'])

# Imputar MUNICIPIO_NACIMIENTO con la moda
if 'MUNICIPIO_NACIMIENTO' in df.columns:
    moda_municipio = df['MUNICIPIO_NACIMIENTO'].mode()[0]
    df['MUNICIPIO_NACIMIENTO'] = df['MUNICIPIO_NACIMIENTO'].fillna(moda_municipio)

# 2. Imputar PUNTAJE_ADMISION por grupo PLAN (puedes cambiar mean() si prefieres)
df['PUNTAJE_ADMISION'] = df.groupby('PLAN')['PUNTAJE_ADMISION'].transform(
    lambda x: x.fillna(x.mean())
)

# 3. Imputar PAPA y PROME_ACADÉMICO usando MICE
mice_vars = ['PAPA', 'PROME_ACADE']
imp_mice = IterativeImputer(random_state=0)
df[mice_vars] = imp_mice.fit_transform(df[mice_vars])

# Guardar el resultado
df.to_excel('df_objetivo/df_objetivo_imputado.xlsx', index=False)

# %%
df.head()
# Out:
#              SEDE       PLAN  AVANCE_CARRERA  \
# 0  SEDE DE LA PAZ  GEOGRAFÍA            80.9
# 1  SEDE DE LA PAZ   BIOLOGÍA            84.4
# 2  SEDE DE LA PAZ  GEOGRAFÍA            91.5
# 3  SEDE DE LA PAZ   BIOLOGÍA            63.1
# 4  SEDE DE LA PAZ   BIOLOGÍA            69.8
#
#                           DOCUMENTO  \
# 0  5d632a6eaf169c11bc93c3f850da3202
# 1  6612ea9bc40e7fa67c2b606f4044bbdd
# 2  5191f7684d12c135e863f2b1429516dd
# 3  fa7bc24f61ad5539ba718ad7fc165d6b
# 4  93bebfeb23ef1396d7251da5bc7519d6
#
#                                            SUBACCESO APERTURA  GENERO  EDAD  \
# 0  PROGRAMA DE ADMISIÓN ESPECIAL PARA LOS PROGRAM...  2019-2S  HOMBRE    22
# 1  PROGRAMA DE ADMISIÓN ESPECIAL PARA LOS PROGRAM...  2019-2S  HOMBRE    23
# 2  PROGRAMA DE ADMISIÓN ESPECIAL PARA LOS PROGRAM...  2019-2S   MUJER    37
# 3  PROGRAMA DE ADMISIÓN ESPECIAL PARA LOS PROGRAM...  2020-1S   MUJER    21
# 4  PROGRAMA DE ADMISIÓN ESPECIAL PARA LOS PROGRAM...  2020-1S   MUJER    22
#
#    NUMERO_MATRICULAS  PAPA  ...  NACIONALIDAD  VICTIMAS_DEL_CONFLICTO  \
# 0                 11   3.9  ...      COLOMBIA                      NO
# 1                 11   4.1  ...      COLOMBIA                      NO
# 2                 11   3.8  ...      COLOMBIA                      NO
# 3                 10   3.7  ...      COLOMBIA                      NO
# 4                 10   3.7  ...      COLOMBIA                      NO
#
#    DISCAPACIDAD CARACTER_COLEGIO MUNICIPIO_RESIDENCIA_FAM  \
# 0            NO  Plantel Oficial              CHIMICHAGUA
# 1            NO  Plantel Oficial               VALLEDUPAR
# 2            NO  Plantel Oficial                   LA PAZ
# 3            NO  Plantel Oficial          AGUSTÍN CODAZZI
# 4            NO  Plantel Oficial               VALLEDUPAR
#
#                                          NODO_INICIO PUNTAJE_ADMISION  \
# 0  Estudiantes que deben nivelar - Excepción COVI...       395.394288
# 1        Estudiantes que deben nivelar 3 asignaturas       473.547606
# 2        Estudiantes que deben nivelar 3 asignaturas       395.394288
# 3        Estudiantes que deben nivelar 3 asignaturas       473.547606
# 4        Estudiantes que deben nivelar 3 asignaturas       473.547606
#
#   AVANCE_ESPERADO ATRASO_PORCENTUAL RIESGO_DESERCION
# 0              88               7.1                0
# 1              88               3.6                0
# 2              88               0.0                0
# 3              80              16.9                0
# 4              80              10.2                0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1283 entries, 0 to 1282
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEDE                      1283 non-null   object
#  1   PLAN                      1283 non-null   object
#  2   AVANCE_CARRERA            1283 non-null   float64
#  3   DOCUMENTO                 1283 non-null   object
#  4   SUBACCESO                 1283 non-null   object
#  5   APERTURA                  1283 non-null   object
#  6   GENERO                    1283 non-null   object
#  7   EDAD                      1283 non-null   int64
#  8   NUMERO_MATRICULAS         1283 non-null   int64
#  9   PAPA                      1283 non-null   float64
#  10  PROME_ACADE               1283 non-null   float64
#  11  PBM_CALCULADO             1283 non-null   int64
#  12  ESTRATO                   1283 non-null   int64
#  13  MUNICIPIO_NACIMIENTO      1283 non-null   object
#  14  NACIONALIDAD              1283 non-null   object
#  15  VICTIMAS_DEL_CONFLICTO    1283 non-null   object
#  16  DISCAPACIDAD              1283 non-null   object
#  17  CARACTER_COLEGIO          1283 non-null   object
#  18  MUNICIPIO_RESIDENCIA_FAM  1283 non-null   object
#  19  NODO_INICIO               1283 non-null   object
#  20  PUNTAJE_ADMISION          1283 non-null   float64
#  21  AVANCE_ESPERADO           1283 non-null   int64
#  22  ATRASO_PORCENTUAL         1283 non-null   float64
#  23  RIESGO_DESERCION          1283 non-null   int64
# dtypes: float64(5), int64(6), object(13)
# memory usage: 240.7+ KB
